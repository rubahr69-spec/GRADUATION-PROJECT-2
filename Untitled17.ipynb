# %%
# !pip install radon bandit pandas scipy matplotlib numpy -q

# %%
import os
os.makedirs("repos", exist_ok=True)
# %cd repos
# نستنسخ عيّنات من مكتبات حقيقية عبر الفئات الخمس
# !git clone --depth 1 https://github.com/pallets/flask.git
# !git clone --depth 1 https://github.com/psf/requests.git
# !git clone --depth 1 https://github.com/networkx/networkx.git
# !git clone --depth 1 https://github.com/pandas-dev/pandas.git
# !git clone --depth 1 https://github.com/paramiko/paramiko.git
# %cd ..
# Out:
# /content/repos
# fatal: destination path 'flask' already exists and is not an empty directory.
# fatal: destination path 'requests' already exists and is not an empty directory.
# fatal: destination path 'networkx' already exists and is not an empty directory.
# fatal: destination path 'pandas' already exists and is not an empty directory.
# fatal: destination path 'paramiko' already exists and is not an empty directory.
# /content

# %%
# %cd repos
# legacy_mixed (كانت صفر)
# !git clone --depth 1 https://github.com/celery/celery.git
# !git clone --depth 1 https://github.com/matplotlib/matplotlib.git
# security_sensitive (كانت 9)
# !git clone --depth 1 https://github.com/pyca/cryptography.git
# !git clone --depth 1 https://github.com/django/django.git
# clean_documented (كانت 12)
# !git clone --depth 1 https://github.com/encode/httpx.git
# !git clone --depth 1 https://github.com/pydantic/pydantic.git
# %cd ..
# Out:
# /content/repos
# fatal: destination path 'celery' already exists and is not an empty directory.
# fatal: destination path 'matplotlib' already exists and is not an empty directory.
# fatal: destination path 'cryptography' already exists and is not an empty directory.
# fatal: destination path 'django' already exists and is not an empty directory.
# fatal: destination path 'httpx' already exists and is not an empty directory.
# fatal: destination path 'pydantic' already exists and is not an empty directory.
# /content

# %%
# !python 01_build_sample.py --repos-dir ./repos --out ./E0_sample --n 120
# Out:
# Held-out filenames excluded: 0
#   clean_documented    : 46 substantive candidates
#   complex_algorithms  : 94 substantive candidates
#   security_sensitive  : 308 substantive candidates
#   ml_data_code        : 98 substantive candidates
#   legacy_mixed        : 194 substantive candidates
#
# Built 120 samples → E0_sample
# Per category: {'security_sensitive': 24, 'complex_algorithms': 24, 'ml_data_code': 24, 'clean_documented': 24, 'legacy_mixed': 24}
# Per member (sequential blocks):
#   Sarah   :  30 files  [E0_001 … E0_030]
#   Hala    :  30 files  [E0_031 … E0_060]
#   Ruba    :  30 files  [E0_061 … E0_090]
#   Huda    :  30 files  [E0_091 … E0_120]
# Each member runs all 3 judges on her files.
